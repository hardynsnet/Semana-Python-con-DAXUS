# %% [markdown]
# # Proyecto 01

# %% [markdown]
# ## Mostrar información al usuario
# * print()

# %%
# Shift + Enter para ejecutar
print("Semana de Python en la práctica");
print('Harley es el mejor estudiante')
# Out:
# Semana de Python en la práctica
# Harley es el mejor estudiante

# %% [markdown]
# # Recibir información del usuario
# * input()

# %%
input("Escriba su nombre: ")
input("Escriba su clave: ")
# Out:
# '1234'

# %% [markdown]
# # Almacenar variables

# %%
proyecto = "Mi primer proyecto en Python"

# %%
print(proyecto)
# Out:
# Mi primer proyecto en Python

# %%
numero = 10

# %%
print(numero)
# Out:
# 10

# %% [markdown]
# # Mezclando los conceptos aprendidos

# %%
proyecto = input("Escriba el nombre del proyecto: ")
horas_estimadas = input("Escriba las horas que va a dedicar al proyecto")
valor_hora = input("¿Cuál es el valor de la hora trabajada?")
plazo_estimado = input("¿Cual es el plazo estimado para el proyecto?")

# %%
"""
Se puede ahorrar las líneas así:
print(proyecto, horas_estimadas, valor_hora, plazo_estimado)
"""
print(proyecto)
print(horas_estimadas)
print(valor_hora)
print(plazo_estimado)
# Out:
# El mejor proyecto con Python
# 120
# 40
# 2 meses

# %% [markdown]
# # Calculos con Python

# %%
print(10+4)
print(123-23)
print(12*3)
print(10/2)
# Out:
# 14
# 100
# 36
# 5.0

# %% [markdown]
# # Calculando el valor total del Proyecto

# %%
valor_total = int(horas_estimadas) * int(valor_hora)

# %%
print(valor_total)
# Out:
# 4800

# %% [markdown]
# ## Generando archivos PDF del presupuesto
# * Crear el archivo PDF
# * Definir un tipo de letra
# * Llenamos el documento
# * Guardar el entregable

# %%
# Pasos 
# 1. Instalar la libreria (!pip install fpdf)
# !pip install fpdf <- Las bibliotecas se instalan así

# %%
from fpdf import FPDF

# %%
pdf = FPDF() # Creamos el archivo
pdf.add_page() # Creamos la página
pdf.set_font("Arial") # Le establecemos la fuente

pdf.image("Template.png", 0, 0) # A partir de esta imagen, plasma la información

# El texto se agrega aquí
pdf.text(115, 145, proyecto)
pdf.text(115, 160, horas_estimadas)
pdf.text(115, 175, valor_hora)
pdf.text(115, 190, plazo_estimado)
pdf.text(115, 205, str(valor_total))

pdf.output("Presupuesto.pdf") # Siempre especificar la extensión
# Out:
# ''
